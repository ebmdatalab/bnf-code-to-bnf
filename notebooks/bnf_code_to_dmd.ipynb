# %% [markdown]
# # Mapping BNF codes to dm+d - Update November 2024

# %% [markdown]
# We have had a request from NHS England:
#
# >Our initial need is to have a reference file that can be used to map data in BNF code form (from NHS BSA) to drug information in dm+d (SNOMED) form (at VMP/AMP level but also with VTM information).
#
# We hold this information in the BQ database, and should be able to create a query to deliver this need.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
import seaborn as sns
from matplotlib.dates import  DateFormatter
# %matplotlib inline
from ebmdatalab import bq
from ebmdatalab import charts
from ebmdatalab import maps
import datetime
import openpyxl

# %% [markdown]
# ## Create data from BigQuery

# %%
sql = """
  SELECT
  "vmp" AS type, # create type column, shows whether VMP or AMP
  vmp.id AS id, # VMP code
  vmp.nm AS nm, # VMP name
  vmp.vtm AS vtm, # VTM code
  vtm.nm AS vtm_nm, # VTM name
  bnf_code, # BNF code
  vpidprev AS vmp_previous, # Previous VMP code
  vpiddt AS vmp_previous_date # Date that previous VMP code changed
FROM
  ebmdatalab.dmd.vmp_full AS vmp
LEFT OUTER JOIN
  dmd.vtm AS vtm
ON
  vmp.vtm = vtm.id

UNION ALL # join VMP and AMP tables together to form single table
SELECT
  "amp" AS type,
  amp.id,
  amp.descr,
  vmp.vtm AS vtm,
  vtm.nm AS vtm_nm,
  amp.bnf_code AS bnf_code,
  NULL AS amp_previous,
  NULL AS amp_previous_date
FROM
  ebmdatalab.dmd.amp_full AS amp
INNER JOIN
  dmd.vmp AS vmp # join VMP to AMP table to get VMP codes to obtain VTM information
ON
  amp.vmp = vmp.id
LEFT OUTER JOIN
  dmd.vtm AS vtm
ON
  vmp.vtm = vtm.id
  """

exportfile = os.path.join("..","data","dmd_df.csv")
dmd_df = bq.cached_read(sql, csv_path=exportfile, use_cache=False)
exportfile2 = os.path.join("..","data","bnf_to_dmd.csv")
dmd_df['id'] = dmd_df['id'].astype('Int64')  # ensure csv is integer
dmd_df['vtm'] = dmd_df['vtm'].astype('Int64') # ensure csv is integer
dmd_df['vmp_previous'] = dmd_df['vmp_previous'].astype('Int64') # ensure csv is integer
exportfile2 = os.path.join("..","data","bnf_to_dmd.csv")
dmd_df.to_csv(exportfile2) # export integer version
# Out:
# Downloading: 100%|██████████| 182104/182104 [00:19<00:00, 9151.58rows/s]

# %%
dmd_df.head()
# Out:
#   type         id                                                 nm  \
# 0  vmp   68461003                                     Lubricant gels
# 1  vmp  134619001  Doxorubicin (liposomal) 50mg/25ml solution for...
# 2  vmp  134754002            Carmellose 1% eye drops 0.4ml unit dose
# 3  vmp  318076002  Spironolactone 5mg/5ml oral suspension sugar free
# 4  vmp  318077006  Spironolactone 10mg/5ml oral suspension sugar ...
#
#            vtm          vtm_nm bnf_code vmp_previous vmp_previous_date
# 0          NaN            None     None  3.48531e+15        2006-01-04
# 1          NaN            None     None          NaN               NaT
# 2  775072005.0      Carmellose     None          NaN               NaT
# 3  777603002.0  Spironolactone     None          NaN               NaT
# 4  777603002.0  Spironolactone     None          NaN               NaT

# %% [markdown]
# As we can see from above we appear to have successfully imported all `VMPs` and `AMPs`.  However, there are some products which either do not have a `VTM` or `bnf_code`.  We will explore this further below.

# %% [markdown]
# #### Check data with 12 months of primary care prescribing data

# %% [markdown]
# Importing prescribing data from BigQuery to check the impact of "missing" data

# %%
sql = """
SELECT
  bnf_code,
  bnf_name,
  SUM(items) AS items
FROM
  ebmdatalab.hscic.normalised_prescribing AS rx
WHERE
  month BETWEEN '2023-09-01'
  AND '2024-08-01'
GROUP BY
  bnf_name,
  bnf_code
  """

exportfile = os.path.join("..","data","rx_df.csv")
rx_df = bq.cached_read(sql, csv_path=exportfile, use_cache=True)

# %%
rx_df.head()
# Out:
#           bnf_code                                           bnf_name    items
# 0  0202020L0AABBBB                            Furosemide 20mg tablets  4268985
# 1  0106040G0AAAAAA               Lactulose 3.1-3.7g/5ml oral solution  2455918
# 2  040201060AAACAC                            Olanzapine 10mg tablets   738192
# 3  0601011A0BDABAC  Trurapi 100units/ml inj 3ml pre-filled Solosta...    93493
# 4  1502010J0AABDBD  Lidocaine 50mg/5ml (1%) solution for injection...    97540

# %% [markdown]
# We can now merge the two dataframes on BNF code

# %%
test_df = pd.merge(dmd_df, rx_df, left_on='bnf_code', right_on='bnf_code', how='right')

# %%
test_df.head()
# Out:
#   type            id                                                 nm  \
# 0  vmp  7.217100e+13  Tetanus immunoglobulin human 250unit solution ...
# 1  amp  4.953011e+15  Tetanus immunoglobulin human 250unit solution ...
# 2  vmp  1.160810e+14                Imiquimod 3.75% cream 250mg sachets
# 3  vmp  1.162810e+14                    Lidocaine 5% medicated plasters
# 4  amp  4.278981e+16   Lidocaine 5% medicated plasters (Grunenthal Ltd)
#
#            vtm                        vtm_nm         bnf_code vmp_previous  \
# 0  777724003.0  Tetanus immunoglobulin human  1405020A0AAABAB  3.33769e+08
# 1  777724003.0  Tetanus immunoglobulin human  1405020A0AAABAB          NaN
# 2  776315001.0                     Imiquimod  1307000V0AAABAB  4.44988e+08
# 3  776528009.0                     Lidocaine  1502010J0AAELEL  3.76491e+08
# 4  776528009.0                     Lidocaine  1502010J0AAELEL         None
#
#   vmp_previous_date                                        bnf_name   items
# 0        2022-01-12  Tetanus immunoglobulin human 250unit inj vials      44
# 1               NaT  Tetanus immunoglobulin human 250unit inj vials      44
# 2        2022-07-29             Imiquimod 3.75% cream 250mg sachets     985
# 3        2022-07-29                 Lidocaine 5% medicated plasters  103102
# 4               NaT                 Lidocaine 5% medicated plasters  103102

# %% [markdown]
# We can now check by seeing which items prescribed which don't have a corresponding `dm+d` code

# %%
test_df_no_dmd = test_df[test_df['id'].isnull()].sort_values(by='items', ascending=False) # filter only prescribing which has a null VMP or AMP
test_df_no_dmd.head()
# Out:
#        type  id   nm  vtm vtm_nm         bnf_code vmp_previous  \
# 105736  NaN NaN  NaN  NaN    NaN  190201000AABLBL          NaN
# 105738  NaN NaN  NaN  NaN    NaN  190201000AABPBP          NaN
# 105737  NaN NaN  NaN  NaN    NaN  190201000AABNBN          NaN
# 105743  NaN NaN  NaN  NaN    NaN  0407020A0AACDCD          NaN
# 105742  NaN NaN  NaN  NaN    NaN  0407020A0AACFCF          NaN
#
#        vmp_previous_date                                        bnf_name  \
# 105736               NaT              Exception Handler Unspecified Item
# 105738               NaT  Exception Handler High Volume Unspecified Item
# 105737               NaT    Exception Handler Discount Not Deducted Item
# 105743               NaT        Fentanyl 400microgram sublingual tablets
# 105742               NaT         Fentanyl 67microgram sublingual tablets
#
#          items
# 105736  221383
# 105738   65058
# 105737   26390
# 105743      16
# 105742       3

# %% [markdown]
# We can see from the above there are very few items apart from "unspecified item", which by definition cannot have a BNF code.

# %% [markdown]
# The other part of the request was to link `VTM` codes.  We can also check which drugs do not link to a `VTM`.

# %%
test_vtm_no_dmd  = test_df[test_df['vtm'].isnull()].sort_values(by='items', ascending=False)

# %%
test_vtm_no_dmd.head(30)
# Out:
#        type            id                                                 nm  \
# 101895  amp  3.909461e+16  FreeStyle Libre 2 Sensor (Abbott Laboratories ...
# 62884   amp  1.742061e+16  Laxido Orange oral powder sachets sugar free (...
# 880     amp  2.239391e+16  Macrogol compound oral powder sachets sugar fr...
# 884     amp  2.840711e+16  Macrogol compound oral powder sachets sugar fr...
# 881     amp  2.267331e+16  Macrogol compound oral powder sachets sugar fr...
# 882     amp  2.437791e+16  Macrogol compound oral powder sachets sugar fr...
# 883     amp  2.455401e+16  Macrogol compound oral powder sachets sugar fr...
# 879     amp  2.179041e+16  Macrogol compound oral powder sachets sugar fr...
# 875     vmp  3.591211e+15  Macrogol compound oral powder sachets NPF suga...
# 876     amp  1.550391e+16  Macrogol compound oral powder sachets sugar fr...
# 877     amp  1.644631e+16  Macrogol compound oral powder sachets sugar fr...
# 878     amp  1.928291e+16  Macrogol compound oral powder sachets sugar fr...
# 885     amp  2.877031e+16  Macrogol compound oral powder sachets sugar fr...
# 886     amp  3.355801e+16  Macrogol compound oral powder sachets sugar fr...
# 887     amp  3.903421e+16  Macrogol compound oral powder sachets sugar fr...
# 888     amp  4.228521e+16  Macrogol compound oral powder sachets NPF suga...
# 35693   amp  5.536110e+14        Dermol 500 lotion (Dermal Laboratories Ltd)
# 85672   amp  2.796701e+16          Epimax original cream (Aspire Pharma Ltd)
# 35625   amp  5.077110e+14                    Otomize ear spray (Teva UK Ltd)
# 64167   amp  1.783511e+16  Medi Derma-S barrier cream (Medicareplus Inter...
# 11561   vmp  3.482051e+16                  Vitamin B compound strong tablets
# 11565   amp  3.306611e+15  Vitamin B compound strong tablets (Kent Pharma...
# 11567   amp  9.798711e+15  Vitamin B compound strong tablets (Almus Pharm...
# 11564   amp  3.305411e+15  Vitamin B compound strong tablets (The Boots C...
# 11563   amp  3.303311e+15  Vitamin B compound strong tablets (Accord-UK Ltd)
# 11562   amp  2.918911e+15  Vitamin B compound strong tablets (A A H Pharm...
# 11566   amp  3.307111e+15  Vitamin B compound strong tablets (Alliance He...
# 11568   amp  1.416591e+16  Vitamin B compound strong tablets (Healthcare ...
# 11569   amp  1.597891e+16  Vitamin B compound strong tablets (Zanza Speci...
# 11571   amp  3.281171e+16  Vitamin B compound strong tablets (Genesis Pha...
#
#         vtm vtm_nm         bnf_code vmp_previous vmp_previous_date  \
# 101895  NaN   None      21480000101         None               NaT
# 62884   NaN   None  0106040M0BCACAA          NaN               NaT
# 880     NaN   None  0106040M0AAAAAA         None               NaT
# 884     NaN   None  0106040M0AAAAAA         None               NaT
# 881     NaN   None  0106040M0AAAAAA         None               NaT
# 882     NaN   None  0106040M0AAAAAA         None               NaT
# 883     NaN   None  0106040M0AAAAAA         None               NaT
# 879     NaN   None  0106040M0AAAAAA         None               NaT
# 875     NaN   None  0106040M0AAAAAA          NaN               NaT
# 876     NaN   None  0106040M0AAAAAA          NaN               NaT
# 877     NaN   None  0106040M0AAAAAA          NaN               NaT
# 878     NaN   None  0106040M0AAAAAA         None               NaT
# 885     NaN   None  0106040M0AAAAAA         None               NaT
# 886     NaN   None  0106040M0AAAAAA         None               NaT
# 887     NaN   None  0106040M0AAAAAA         None               NaT
# 888     NaN   None  0106040M0AAAAAA         None               NaT
# 35693   NaN   None  130201000BBICBW          NaN               NaT
# 85672   NaN   None      21220000241         None               NaT
# 35625   NaN   None  120101050BCAAAB          NaN               NaT
# 64167   NaN   None      23803068001         None               NaT
# 11561   NaN   None  0906027G0AAABAB  3.29298e+08        2017-10-05
# 11565   NaN   None  0906027G0AAABAB          NaN               NaT
# 11567   NaN   None  0906027G0AAABAB          NaN               NaT
# 11564   NaN   None  0906027G0AAABAB          NaN               NaT
# 11563   NaN   None  0906027G0AAABAB          NaN               NaT
# 11562   NaN   None  0906027G0AAABAB          NaN               NaT
# 11566   NaN   None  0906027G0AAABAB          NaN               NaT
# 11568   NaN   None  0906027G0AAABAB          NaN               NaT
# 11569   NaN   None  0906027G0AAABAB          NaN               NaT
# 11571   NaN   None  0906027G0AAABAB         None               NaT
#
#                                                  bnf_name    items
# 101895                           FreeStyle Libre 2 Sensor  2968952
# 62884        Laxido Orange oral powder sachets sugar free  2778960
# 880     Macrogol compound oral powder sachets NPF suga...  2149596
# 884     Macrogol compound oral powder sachets NPF suga...  2149596
# 881     Macrogol compound oral powder sachets NPF suga...  2149596
# 882     Macrogol compound oral powder sachets NPF suga...  2149596
# 883     Macrogol compound oral powder sachets NPF suga...  2149596
# 879     Macrogol compound oral powder sachets NPF suga...  2149596
# 875     Macrogol compound oral powder sachets NPF suga...  2149596
# 876     Macrogol compound oral powder sachets NPF suga...  2149596
# 877     Macrogol compound oral powder sachets NPF suga...  2149596
# 878     Macrogol compound oral powder sachets NPF suga...  2149596
# 885     Macrogol compound oral powder sachets NPF suga...  2149596
# 886     Macrogol compound oral powder sachets NPF suga...  2149596
# 887     Macrogol compound oral powder sachets NPF suga...  2149596
# 888     Macrogol compound oral powder sachets NPF suga...  2149596
# 35693                                   Dermol 500 lotion  2049895
# 85672                               Epimax original cream  1416706
# 35625                                   Otomize ear spray  1361262
# 64167                          Medi Derma-S barrier cream   914676
# 11561                   Vitamin B compound strong tablets   911934
# 11565                   Vitamin B compound strong tablets   911934
# 11567                   Vitamin B compound strong tablets   911934
# 11564                   Vitamin B compound strong tablets   911934
# 11563                   Vitamin B compound strong tablets   911934
# 11562                   Vitamin B compound strong tablets   911934
# 11566                   Vitamin B compound strong tablets   911934
# 11568                   Vitamin B compound strong tablets   911934
# 11569                   Vitamin B compound strong tablets   911934
# 11571                   Vitamin B compound strong tablets   911934

# %%
group_vtm_no_dmd = test_vtm_no_dmd.groupby(['bnf_name'])[['items']].mean().sort_values(by='items', ascending=False)

# %%
group_vtm_no_dmd.head(30)
# Out:
#                                                       items
# bnf_name
# FreeStyle Libre 2 Sensor                            2968952
# Laxido Orange oral powder sachets sugar free        2778960
# Macrogol compound oral powder sachets NPF sugar...  2149596
# Dermol 500 lotion                                   2049895
# Epimax original cream                               1416706
# Otomize ear spray                                   1361262
# Medi Derma-S barrier cream                           914676
# Vitamin B compound strong tablets                    911934
# GlucoRx Nexus testing strips                         853344
# AeroChamber Plus                                     607542
# GlucoRx lancets 0.31mm/30gauge                       599562
# WaveSense JAZZ testing strips                        595663
# Evorel Sequi patches                                 581031
# Hylo Night eye ointment preservative free            576723
# Aveeno cream                                         574482
# Xailin Night eye ointment preservative free          544005
# Sharpsafe disposal unit 1 litre                      543940
# BD Viva hypodermic insulin needles for pre-fill...   536588
# Sharpsguard disposal unit 1 litre                    523795
# AeroChamber Plus with mask                           517741
# Forceval capsules                                    490371
# TEE2 testing strips                                  469453
# GlucoRx Q testing strips                             462180
# Movicol Paediatric Plain oral powder 6.9g sachets    444103
# Proshield Plus skin protective                       440970
# FastClix lancets 0.3mm/30gauge                       432919
# Dermol cream                                         427988
# GlucoRx CarePoint hypod insulin needles for pre...   411160
# Cavilon Durable barrier cream                        404002
# Finetest Lite testing strips                         399723

# %% [markdown]
# The largest number of prescribing items with a `NULL` `VTM` are either a) where they are not drugs, but appliances or devices (such as Freestyle Libre), OR where the drug has more than 3 ingredients.  In this case (such as Laxido) no VTM is assigned to the formulation in the dm+d.  Therefore it appears that the table accurately reflects what the dm+d says.
